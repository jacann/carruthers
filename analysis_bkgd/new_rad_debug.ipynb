# %%
import numpy as np


start = np.datetime64('2026-01-01')
end = np.datetime64('2026-02-03')

#start = start.astype('datetime64[M]')
#end = end.astype('datetime64[M]')

range_day_dt = np.arange(start, end, dtype='datetime64[D]')
range_day_str = np.strings.replace(np.datetime_as_string(range_day_dt), "-", "")

#end_date_p1 = end_date + np.timedelta64(1, 'D')

range_month_dt = range_day_dt.astype('datetime64[M]')
range_month_str = np.strings.replace(np.datetime_as_string(range_month_dt), "-", "/")
range_month_dt


[True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False, True, False]
